# %% [markdown]
# # First Program in Jupyter Notebook
#
# **Author:** Santosh Cheruku
# **Date:**   06/02/2019

# %%
import networkx as nx;
import matplotlib.pyplot as plt;

G = nx.Graph()

G.add_nodes_from(['Andre', 'Carol', 'Fernando', 'Heather', 'Ike', 'Jane', 'Beverly', 'Ed', 'Garth', 'Diane'])


G.add_edge('Andre', 'Carol');
G.add_edge('Carol', 'Fernando');
G.add_edge('Fernando', 'Heather');
G.add_edge('Heather', 'Ike');
G.add_edge('Ike', 'Jane');
G.add_edge('Andre', 'Beverly');
G.add_edge('Beverly', 'Ed');
G.add_edge('Ed', 'Garth');
G.add_edge('Garth', 'Diane');
G.add_edge('Diane', 'Ed');
G.add_edge('Diane', 'Andre');
G.add_edge('Diane', 'Carol');
G.add_edge('Andre', 'Fernando');
G.add_edge('Fernando', 'Garth');

nx.draw(G, with_labels=True, font_weight='bold')

print("Total Nodes = ", G.number_of_nodes())
print("Total Edges = ", G.number_of_edges())
# Out:
# Total Nodes =  10
# Total Edges =  14
